# %%
### Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# PART 1

# %%
### Read in datasets
avg_temp = pd.read_csv('avg_temp.csv')
avg_temp = avg_temp.rename(columns = {'Average_Fahrenheit_Temperature' : 'avg_temp'})
avg_temp
# Out:
#      Year  avg_temp
# 0    1900      53.9
# 1    1901      53.5
# 2    1902      52.1
# 3    1903      50.6
# 4    1904      51.8
# ..    ...       ...
# 119  2019      53.5
# 120  2020      53.1
# 121  2021      54.5
# 122  2022      54.0
# 123  2023      53.9
#
# [124 rows x 2 columns]

# %%
avg_temp.plot(x='Year', y='avg_temp')
# Out:
# <Axes: xlabel='Year'>

# %%
emissions = pd.read_csv('emissions_by_country.csv')
emissions
# Out:
#             Entity Code  Year  Annual CO2 emissions (zero filled)
# 0      Afghanistan  AFG  1750                                   0
# 1      Afghanistan  AFG  1751                                   0
# 2      Afghanistan  AFG  1752                                   0
# 3      Afghanistan  AFG  1753                                   0
# 4      Afghanistan  AFG  1754                                   0
# ...            ...  ...   ...                                 ...
# 66932     Zimbabwe  ZWE  2016                            10737567
# 66933     Zimbabwe  ZWE  2017                             9581633
# 66934     Zimbabwe  ZWE  2018                            11854367
# 66935     Zimbabwe  ZWE  2019                            10949084
# 66936     Zimbabwe  ZWE  2020                            10531342
#
# [66937 rows x 4 columns]

# %%
emissions
emissions_cleaned = emissions[emissions['Entity'] == 'United States']
emissions_cleaned = emissions_cleaned[emissions_cleaned['Year'] >= 1900]
emissions_cleaned = emissions_cleaned.drop('Code', axis=1)
emissions_cleaned = emissions_cleaned.rename(columns = {'Annual CO2 emissions (zero filled)': 'Emissions'})
emissions_cleaned
# Out:
#               Entity  Year   Emissions
# 63835  United States  1900   662738378
# 63836  United States  1901   721527528
# 63837  United States  1902   764495745
# 63838  United States  1903   894406917
# 63839  United States  1904   882057522
# ...              ...   ...         ...
# 63951  United States  2016  5248023931
# 63952  United States  2017  5207751278
# 63953  United States  2018  5375490614
# 63954  United States  2019  5255816207
# 63955  United States  2020  4712770573
#
# [121 rows x 3 columns]

# %%
emissions_cleaned.plot(x='Year', y='Emissions')
# Out:
# <Axes: xlabel='Year'>

# %%
joined = pd.merge(avg_temp, emissions_cleaned, on = 'Year', how = 'inner')
joined = joined[joined['Year'] >= 1960]
joined
# Out:
#      Year  avg_temp         Entity   Emissions
# 60   1960      51.9  United States  2897138041
# 61   1961      52.3  United States  2886696092
# 62   1962      50.6  United States  2993718164
# 63   1963      50.9  United States  3126294023
# 64   1964      48.3  United States  3264110570
# ..    ...       ...            ...         ...
# 116  2016      54.4  United States  5248023931
# 117  2017      54.7  United States  5207751278
# 118  2018      53.7  United States  5375490614
# 119  2019      53.5  United States  5255816207
# 120  2020      53.1  United States  4712770573
#
# [61 rows x 4 columns]

# %%
plt.scatter(joined['avg_temp'], joined['Emissions'])
plt.xlabel('Average Temperature')
plt.ylabel('CO2 Emissions')

# %%
plt.scatter(joined['avg_temp'], joined['Emissions'])
plt.xlabel('Average Temperature')
plt.ylabel('CO2 Emissions')
# Out:
# Text(0, 0.5, 'CO2 Emissions')

# %% [markdown]
# PART 2

# %%
sea_level = pd.read_csv('sea level.csv')
sea_level
# Out:
#     Year  Adjusted sea level (inches)
# 0   1960                     4.503937
# 1   1961                     4.748031
# 2   1962                     4.543307
# 3   1963                     4.480315
# 4   1964                     4.169291
# 5   1965                     4.610236
# 6   1966                     4.397638
# 7   1967                     4.452756
# 8   1968                     4.484252
# 9   1969                     4.751968
# 10  1970                     4.677165
# 11  1971                     4.881890
# 12  1972                     5.240157
# 13  1973                     5.003937
# 14  1974                     5.472441
# 15  1975                     5.409449
# 16  1976                     5.370079
# 17  1977                     5.303150
# 18  1978                     5.555118
# 19  1979                     5.362205
# 20  1980                     5.598425
# 21  1981                     6.086614
# 22  1982                     5.858268
# 23  1983                     6.188976
# 24  1984                     6.153543
# 25  1985                     5.748031
# 26  1986                     5.771654
# 27  1987                     5.795276
# 28  1988                     5.980315
# 29  1989                     6.157480
# 30  1990                     6.248031
# 31  1991                     6.346457
# 32  1992                     6.374016
# 33  1993                     6.303150
# 34  1994                     6.507874
# 35  1995                     6.622047
# 36  1996                     6.783465
# 37  1997                     7.059055
# 38  1998                     6.669291
# 39  1999                     7.003937
# 40  2000                     7.055118
# 41  2001                     7.271654
# 42  2002                     7.366142
# 43  2003                     7.728346
# 44  2004                     7.712598
# 45  2005                     7.716535
# 46  2006                     7.885827
# 47  2007                     7.960630
# 48  2008                     8.303150
# 49  2009                     8.531496
# 50  2010                     8.834646
# 51  2011                     8.897638
# 52  2012                     9.244094
# 53  2013                     8.913386

# %% [markdown]
# PART 3
